# %%
import os
import sys
import pandas as pd
import numpy as np
import re

# %% [markdown]
# - [*sys*: System-specific parameters and functions](https://docs.python.org/3/library/sys.html)
# ```
# notebook_path = !pwd
# prj_path = os.path.abspath(os.path.join(notebook_path[0], '../data/', ''))
# sys.path.append(prj_path)
# print('Added: %s' % prj_path)
# ```
# > Added: /Users/jalfredomb/Documents/repositorios/DSCourse_FMATProfessors/data
#
# - [*os*: Operative System](https://docs.python.org/es/3.10/library/os.html)
#
# ```
# os.listdir('../data/source')
# ```
# > ['Sleep_health_and_lifestyle_dataset.csv']
#
# - [*pandas*](https://pandas.pydata.org/docs/user_guide/10min.html#min)
#     - Series: One dimension arrays
#     - DataFrames: Two dimension data structure
# - [*numpy*: provides a multidimensional array object](https://numpy.org/devdocs/user/quickstart.html)
# - [*matplotlib*: creating static, animated, and interactive visualizations](https://matplotlib.org/stable/tutorials/index.html)

# %%
_PATH_TO_DATA_SOURCE = '../data/source/'
_PATH_TO_DATA_RAW = '../data/raw/'
list_files = os.listdir(_PATH_TO_DATA_SOURCE)
filename = _PATH_TO_DATA_SOURCE+list_files[0]
print(filename)
data_source = pd.read_csv(filename)
data_source
# Out:
# ../data/source/Sleep_health_and_lifestyle_dataset.csv
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# ...

# %%
data_source.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
NB_PARTITIONS = 10
size_partitions = int(np.ceil(len(data_source)/NB_PARTITIONS))
for i in range(NB_PARTITIONS):
    print(i)
    data_i = data_source.iloc[i*size_partitions:i*size_partitions+size_partitions+5].drop(columns=['Sleep Disorder'])
    display(data_i)
    filename_i = _PATH_TO_DATA_RAW+re.sub('.csv','_'+str(i)+'.csv',list_files[0])
    print(filename_i)
    data_i.to_csv(filename_i,index=False)
    
    
data_i = data_source[['Person ID','Sleep Disorder']]
display(data_i)
filename_i = _PATH_TO_DATA_RAW+'Target_Sleep_Disorder.csv'
print(filename_i)
data_i.to_csv(filename_i,index=False)
# Out:
# 0
#     Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0           1    Male   27     Software Engineer             6.1
# 1           2    Male   28                Doctor             6.2
# 2           3    Male   28                Doctor             6.2
# 3           4    Male   28  Sales Representative             5.9
# 4           5    Male   28  Sales Representative             5.9
# 5           6    Male   28     Software Engineer             5.9
# 6           7    Male   29               Teacher             6.3
# 7           8    Male   29                Doctor             7.8
# 8           9    Male   29                Doctor             7.8
# 9          10    Male   29                Doctor             7.8
# 10         11    Male   29                Doctor             6.1
# 11         12    Male   29                Doctor             7.8
# 12         13    Male   29                Doctor             6.1
# ...
